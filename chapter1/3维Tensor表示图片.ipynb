# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
Image.open("./imgs/pytorch.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x300 at 0x2D2B1303898>

# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
pytorch = np.array(Image.open("./imgs/pytorch.jpg").resize((224,224)))
print(pytorch.shape)
pytorch_tensor = torch.from_numpy(pytorch)
pytorch_tensor.size()
plt.imshow(pytorch)
# Out:
# (224, 224, 3)
